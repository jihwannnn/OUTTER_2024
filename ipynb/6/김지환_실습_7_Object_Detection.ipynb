# %% [markdown]
# ### OUTTA AI 부트캠프 딥러닝반 5-2차 실습 : Single Shot Object Detection (YOLO)

# %% [markdown]
# <h4><div style="text-align: right"> Last Edit: July 09, 2024. </div> <br>

# %% [markdown]
# ## 우선, 다음의 코드들을 실행하여 실습에 사용할 데이터셋과 파일들을 현재 ipynb 파일에 연결하도록 하자.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Object_Detection/OD_dataset.zip /content/
# !cp /content/drive/MyDrive/Object_Detection/OD_utill.zip /content/
# !cp /content/drive/MyDrive/Object_Detection/pre_train.pt /content/

# %%
# !unzip "/content/OD_dataset.zip"
# !unzip "/content/OD_utill.zip"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: all_img/2008_004414.jpg
#   inflating: all_img/2008_004422.jpg
#   inflating: all_img/2008_004427.jpg
#   inflating: all_img/2008_004433.jpg
#   inflating: all_img/2008_004458.jpg
#   inflating: all_img/2008_004462.jpg
#   inflating: all_img/2008_004480.jpg
#   inflating: all_img/2008_004488.jpg
#   inflating: all_img/2008_004498.jpg
#   inflating: all_img/2008_004502.jpg
#   inflating: all_img/2008_004505.jpg
#   inflating: all_img/2008_004552.jpg
#   inflating: all_img/2008_004559.jpg
#   inflating: all_img/2008_004583.jpg
#   inflating: all_img/2008_004590.jpg
#   inflating: all_img/2008_004605.jpg
#   inflating: all_img/2008_004613.jpg
#   inflating: all_img/2008_004614.jpg
#   inflating: all_img/2008_004630.jpg
#   inflating: all_img/2008_004631.jpg
#   inflating: all_img/2008_004635.jpg
#   inflating: all_img/2008_004640.jpg
#   inflating: all_img/2008_004648.jpg
#   inflating: all_img/2008_004653.jpg
#   inflating: all_img/2008_004662.jpg
#   inflating: all_img/2008_004667.jpg
#   inflating: all_img/2008_004672.jpg
#   inflating: all_img/2008_004684.jpg
#   inflating: all_img/2008_004704.jpg
#   inflating: all_img/2008_004722.jpg
#   inflating: all_img/2008_004725.jpg
#   inflating: all_img/2008_004726.jpg
#   inflating: all_img/2008_004732.jpg
#   inflating: all_img/2008_004736.jpg
#   inflating: all_img/2008_004739.jpg
#   inflating: all_img/2008_004752.jpg
#   inflating: all_img/2008_004758.jpg
#   inflating: all_img/2008_004760.jpg
#   inflating: all_img/2008_004767.jpg
#   inflating: all_img/2008_004768.jpg
#   inflating: all_img/2008_004771.jpg
#   inflating: all_img/2008_004794.jpg
#   inflating: all_img/2008_004797.jpg
#   inflating: all_img/2008_004802.jpg
#   inflating: all_img/2008_004804.jpg
#   inflating: all_img/2008_004819.jpg
#   inflating: all_img/2008_004821.jpg
#   inflating: all_img/2008_004833.jpg
#   inflating: all_img/2008_004845.jpg
#   inflating: all_img/2008_004847.jpg
#   inflating: all_img/2008_004850.jpg
#   inflating: all_img/2008_004917.jpg
#   inflating: all_img/2008_004923.jpg
#   inflating: all_img/2008_004931.jpg
#   inflating: all_img/2008_004933.jpg
#   inflating: all_img/2008_004935.jpg
#   inflating: all_img/2008_004945.jpg
#   inflating: all_img/2008_004955.jpg
#   inflating: all_img/2008_004967.jpg
#   inflating: all_img/2008_004974.jpg
#   inflating: all_img/2008_004975.jpg
#   inflating: all_img/2008_004981.jpg
#   inflating: all_img/2008_004986.jpg
#   inflating: all_img/2008_004990.jpg
#   inflating: all_img/2008_004995.jpg
#   inflating: all_img/2008_004998.jpg
#   inflating: all_img/2008_005003.jpg
#   inflating: all_img/2008_005013.jpg
#   inflating: all_img/2008_005015.jpg
#   inflating: all_img/2008_005036.jpg
#   inflating: all_img/2008_005051.jpg
#   inflating: all_img/2008_005054.jpg
#   inflating: all_img/2008_005057.jpg
#   inflating: all_img/2008_005061.jpg
#   inflating: all_img/2008_005065.jpg
#   inflating: all_img/2008_005074.jpg
#   inflating: all_img/2008_005078.jpg
#   inflating: all_img/2008_005082.jpg
#   inflating: all_img/2008_005084.jpg
#   inflating: all_img/2008_005088.jpg
#   inflating: all_img/2008_005109.jpg
#   inflating: all_img/2008_005114.jpg
#   inflating: all_img/2008_005123.jpg
#   inflating: all_img/2008_005127.jpg
#   inflating: all_img/2008_005134.jpg
#   inflating: all_img/2008_005137.jpg
#   inflating: all_img/2008_005193.jpg
#   inflating: all_img/2008_005194.jpg
#   inflating: all_img/2008_005196.jpg
#   inflating: all_img/2008_005216.jpg
#   inflating: all_img/2008_005220.jpg
#   inflating: all_img/2008_005221.jpg
#   inflating: all_img/2008_005234.jpg
#   inflating: all_img/2008_005235.jpg
#   inflating: all_img/2008_005240.jpg
#   inflating: all_img/2008_005247.jpg
#   inflating: all_img/2008_005250.jpg
#   inflating: all_img/2008_005252.jpg
#   inflating: all_img/2008_005266.jpg
#   inflating: all_img/2008_005270.jpg
#   inflating: all_img/2008_005272.jpg
#   inflating: all_img/2008_005281.jpg
#   inflating: all_img/2008_005283.jpg
#   inflating: all_img/2008_005288.jpg
#   inflating: all_img/2008_005300.jpg
#   inflating: all_img/2008_005309.jpg
#   inflating: all_img/2008_005310.jpg
#   inflating: all_img/2008_005325.jpg
#   inflating: all_img/2008_005331.jpg
#   inflating: all_img/2008_005333.jpg
#   inflating: all_img/2008_005335.jpg
#   inflating: all_img/2008_005337.jpg
#   inflating: all_img/2008_005346.jpg
#   inflating: all_img/2008_005349.jpg
#   inflating: all_img/2008_005350.jpg
#   inflating: all_img/2008_005356.jpg
#   inflating: all_img/2008_005361.jpg
#   inflating: all_img/2008_005362.jpg
#   inflating: all_img/2008_005363.jpg
#   inflating: all_img/2008_005373.jpg
#   inflating: all_img/2008_005376.jpg
#   inflating: all_img/2008_005378.jpg
#   inflating: all_img/2008_005379.jpg
#   inflating: all_img/2008_005380.jpg
#   inflating: all_img/2008_005382.jpg
#   inflating: all_img/2008_005386.jpg
#   inflating: all_img/2008_005404.jpg
#   inflating: all_img/2008_005405.jpg
#   inflating: all_img/2008_005406.jpg
#   inflating: all_img/2008_005415.jpg
#   inflating: all_img/2008_005421.jpg
#   inflating: all_img/2008_005436.jpg
#   inflating: all_img/2008_005443.jpg
#   inflating: all_img/2008_005449.jpg
#   inflating: all_img/2008_005451.jpg
#   inflating: all_img/2008_005455.jpg
#   inflating: all_img/2008_005460.jpg
#   inflating: all_img/2008_005463.jpg
#   inflating: all_img/2008_005467.jpg
#   inflating: all_img/2008_005469.jpg
#   inflating: all_img/2008_005480.jpg
#   inflating: all_img/2008_005548.jpg
#   inflating: all_img/2008_005550.jpg
#   inflating: all_img/2008_005564.jpg
#   inflating: all_img/2008_005572.jpg
#   inflating: all_img/2008_005573.jpg
#   inflating: all_img/2008_005591.jpg
#   inflating: all_img/2008_005611.jpg
#   inflating: all_img/2008_005614.jpg
#   inflating: all_img/2008_005631.jpg
#   inflating: all_img/2008_005634.jpg
#   inflating: all_img/2008_005636.jpg
#   inflating: all_img/2008_005638.jpg
#   inflating: all_img/2008_005643.jpg
#   inflating: all_img/2008_005656.jpg
#   inflating: all_img/2008_005657.jpg
#   inflating: all_img/2008_005663.jpg
#   inflating: all_img/2008_005673.jpg
#   inflating: all_img/2008_005675.jpg
#   inflating: all_img/2008_005676.jpg
#   inflating: all_img/2008_005679.jpg
#   inflating: all_img/2008_005685.jpg
#   inflating: all_img/2008_005686.jpg
#   inflating: all_img/2008_005699.jpg
#   inflating: all_img/2008_005703.jpg
#   inflating: all_img/2008_005713.jpg
#   inflating: all_img/2008_005716.jpg
#   inflating: all_img/2008_005719.jpg
#   inflating: all_img/2008_005721.jpg
#   inflating: all_img/2008_005727.jpg
#   inflating: all_img/2008_005728.jpg
#   inflating: all_img/2008_005735.jpg
#   inflating: all_img/2008_005777.jpg
#   inflating: all_img/2008_005780.jpg
#   inflating: all_img/2008_005800.jpg
#   inflating: all_img/2008_005805.jpg
#   inflating: all_img/2008_005816.jpg
#   inflating: all_img/2008_005822.jpg
#   inflating: all_img/2008_005823.jpg
#   inflating: all_img/2008_005831.jpg
#   inflating: all_img/2008_005834.jpg
#   inflating: all_img/2008_005839.jpg
#   inflating: all_img/2008_005845.jpg
#   inflating: all_img/2008_005853.jpg
#   inflating: all_img/2008_005860.jpg
#   inflating: all_img/2008_005865.jpg
#   inflating: all_img/2008_005871.jpg
#   inflating: all_img/2008_005873.jpg
#   inflating: all_img/2008_005875.jpg
#   inflating: all_img/2008_005878.jpg
#   inflating: all_img/2008_005883.jpg
#   inflating: all_img/2008_005889.jpg
#   inflating: all_img/2008_005890.jpg
#   inflating: all_img/2008_005891.jpg
#   inflating: all_img/2008_005898.jpg
#   inflating: all_img/2008_005905.jpg
#   inflating: all_img/2008_005916.jpg
#   inflating: all_img/2008_005933.jpg
#   inflating: all_img/2008_005936.jpg
#   inflating: all_img/2008_005943.jpg
#   inflating: all_img/2008_005960.jpg
#   inflating: all_img/2008_005964.jpg
#   inflating: all_img/2008_005970.jpg
#   inflating: all_img/2008_005977.jpg
#   inflating: all_img/2008_005979.jpg
#   inflating: all_img/2008_005980.jpg
#   inflating: all_img/2008_005982.jpg
#   inflating: all_img/2008_005984.jpg
#   inflating: all_img/2008_005989.jpg
#   inflating: all_img/2008_006007.jpg
#   inflating: all_img/2008_006020.jpg
#   inflating: all_img/2008_006034.jpg
#   inflating: all_img/2008_006037.jpg
#   inflating: all_img/2008_006049.jpg
#   inflating: all_img/2008_006050.jpg
#   inflating: all_img/2008_006067.jpg
#   inflating: all_img/2008_006074.jpg
#   inflating: all_img/2008_006081.jpg
#   inflating: all_img/2008_006082.jpg
#   inflating: all_img/2008_006085.jpg
#   inflating: all_img/2008_006130.jpg
#   inflating: all_img/2008_006140.jpg
#   inflating: all_img/2008_006166.jpg
#   inflating: all_img/2008_006169.jpg
#   inflating: all_img/2008_006170.jpg
#   inflating: all_img/2008_006175.jpg
#   inflating: all_img/2008_006178.jpg
#   inflating: all_img/2008_006190.jpg
#   inflating: all_img/2008_006194.jpg
#   inflating: all_img/2008_006200.jpg
#   inflating: all_img/2008_006211.jpg
#   inflating: all_img/2008_006213.jpg
#   inflating: all_img/2008_006218.jpg
#   inflating: all_img/2008_006220.jpg
#   inflating: all_img/2008_006224.jpg
#   inflating: all_img/2008_006225.jpg
#   inflating: all_img/2008_006234.jpg
#   inflating: all_img/2008_006239.jpg
#   inflating: all_img/2008_006240.jpg
#   inflating: all_img/2008_006244.jpg
#   inflating: all_img/2008_006249.jpg
#   inflating: all_img/2008_006269.jpg
#   inflating: all_img/2008_006280.jpg
#   inflating: all_img/2008_006285.jpg
#   inflating: all_img/2008_006294.jpg
#   inflating: all_img/2008_006310.jpg
#   inflating: all_img/2008_006316.jpg
#   inflating: all_img/2008_006320.jpg
#   inflating: all_img/2008_006325.jpg
#   inflating: all_img/2008_006329.jpg
#   inflating: all_img/2008_006335.jpg
#   inflating: all_img/2008_006336.jpg
#   inflating: all_img/2008_006347.jpg
#   inflating: all_img/2008_006351.jpg
#   inflating: all_img/2008_006353.jpg
#   inflating: all_img/2008_006356.jpg
#   inflating: all_img/2008_006359.jpg
#   inflating: all_img/2008_006361.jpg
#   inflating: all_img/2008_006362.jpg
#   inflating: all_img/2008_006364.jpg
#   inflating: all_img/2008_006384.jpg
#   inflating: all_img/2008_006386.jpg
#   inflating: all_img/2008_006394.jpg
#   inflating: all_img/2008_006400.jpg
#   inflating: all_img/2008_006401.jpg
#   inflating: all_img/2008_006403.jpg
#   inflating: all_img/2008_006416.jpg
#   inflating: all_img/2008_006417.jpg
#   inflating: all_img/2008_006474.jpg
#   inflating: all_img/2008_006475.jpg
#   inflating: all_img/2008_006480.jpg
#   inflating: all_img/2008_006483.jpg
#   inflating: all_img/2008_006502.jpg
#   inflating: all_img/2008_006506.jpg
#   inflating: all_img/2008_006511.jpg
#   inflating: all_img/2008_006512.jpg
#   inflating: all_img/2008_006520.jpg
#   inflating: all_img/2008_006522.jpg
#   inflating: all_img/2008_006538.jpg
#   inflating: all_img/2008_006540.jpg
#   inflating: all_img/2008_006546.jpg
#   inflating: all_img/2008_006548.jpg
#   inflating: all_img/2008_006561.jpg
#   inflating: all_img/2008_006564.jpg
#   inflating: all_img/2008_006568.jpg
#   inflating: all_img/2008_006576.jpg
#   inflating: all_img/2008_006578.jpg
#   inflating: all_img/2008_006579.jpg
#   inflating: all_img/2008_006587.jpg
#   inflating: all_img/2008_006599.jpg
#   inflating: all_img/2008_006600.jpg
#   inflating: all_img/2008_006602.jpg
#   inflating: all_img/2008_006604.jpg
#   inflating: all_img/2008_006614.jpg
#   inflating: all_img/2008_006619.jpg
#   inflating: all_img/2008_006621.jpg
#   inflating: all_img/2008_006623.jpg
#   inflating: all_img/2008_006629.jpg
#   inflating: all_img/2008_006634.jpg
#   inflating: all_img/2008_006635.jpg
#   inflating: all_img/2008_006637.jpg
#   inflating: all_img/2008_006638.jpg
#   inflating: all_img/2008_006645.jpg
#   inflating: all_img/2008_006649.jpg
#   inflating: all_img/2008_006656.jpg
#   inflating: all_img/2008_006671.jpg
#   inflating: all_img/2008_006677.jpg
#   inflating: all_img/2008_006682.jpg
#   inflating: all_img/2008_006690.jpg
#   inflating: all_img/2008_006694.jpg
#   inflating: all_img/2008_006700.jpg
#   inflating: all_img/2008_006703.jpg
#   inflating: all_img/2008_006717.jpg
#   inflating: all_img/2008_006718.jpg
#   inflating: all_img/2008_006724.jpg
#   inflating: all_img/2008_006728.jpg
#   inflating: all_img/2008_006743.jpg
#   inflating: all_img/2008_006746.jpg
#   inflating: all_img/2008_006748.jpg
#   inflating: all_img/2008_006753.jpg
#   inflating: all_img/2008_006761.jpg
#   inflating: all_img/2008_006762.jpg
#   inflating: all_img/2008_006765.jpg
#   inflating: all_img/2008_006774.jpg
#   inflating: all_img/2008_006777.jpg
#   inflating: all_img/2008_006778.jpg
#   inflating: all_img/2008_006781.jpg
#   inflating: all_img/2008_006785.jpg
#   inflating: all_img/2008_006793.jpg
#   inflating: all_img/2008_006800.jpg
#   inflating: all_img/2008_006810.jpg
#   inflating: all_img/2008_006811.jpg
#   inflating: all_img/2008_006817.jpg
#   inflating: all_img/2008_006819.jpg
#   inflating: all_img/2008_006832.jpg
#   inflating: all_img/2008_006885.jpg
#   inflating: all_img/2008_006896.jpg
#   inflating: all_img/2008_006907.jpg
#   inflating: all_img/2008_006908.jpg
#   inflating: all_img/2008_006910.jpg
#   inflating: all_img/2008_006920.jpg
#   inflating: all_img/2008_006921.jpg
#   inflating: all_img/2008_006926.jpg
#   inflating: all_img/2008_006936.jpg
#   inflating: all_img/2008_006951.jpg
#   inflating: all_img/2008_006956.jpg
#   inflating: all_img/2008_006959.jpg
#   inflating: all_img/2008_006962.jpg
#   inflating: all_img/2008_006965.jpg
#   inflating: all_img/2008_006967.jpg
#   inflating: all_img/2008_006968.jpg
#   inflating: all_img/2008_006973.jpg
#   inflating: all_img/2008_006980.jpg
#   inflating: all_img/2008_006981.jpg
#   inflating: all_img/2008_006986.jpg
#   inflating: all_img/2008_006999.jpg
#   inflating: all_img/2008_007012.jpg
#   inflating: all_img/2008_007028.jpg
#   inflating: all_img/2008_007034.jpg
#   inflating: all_img/2008_007039.jpg
#   inflating: all_img/2008_007045.jpg
#   inflating: all_img/2008_007057.jpg
#   inflating: all_img/2008_007059.jpg
#   inflating: all_img/2008_007060.jpg
#   inflating: all_img/2008_007064.jpg
#   inflating: all_img/2008_007073.jpg
#   inflating: all_img/2008_007081.jpg
#   inflating: all_img/2008_007082.jpg
#   inflating: all_img/2008_007086.jpg
#   inflating: all_img/2008_007095.jpg
#   inflating: all_img/2008_007096.jpg
#   inflating: all_img/2008_007106.jpg
#   inflating: all_img/2008_007118.jpg
#   inflating: all_img/2008_007130.jpg
#   inflating: all_img/2008_007131.jpg
#   inflating: all_img/2008_007145.jpg
#   inflating: all_img/2008_007151.jpg
#   inflating: all_img/2008_007161.jpg
#   inflating: all_img/2008_007164.jpg
#   inflating: all_img/2008_007165.jpg
#   inflating: all_img/2008_007167.jpg
#   inflating: all_img/2008_007176.jpg
#   inflating: all_img/2008_007179.jpg
#   inflating: all_img/2008_007187.jpg
#   inflating: all_img/2008_007239.jpg
#   inflating: all_img/2008_007256.jpg
#   inflating: all_img/2008_007260.jpg
#   inflating: all_img/2008_007265.jpg
#   inflating: all_img/2008_007269.jpg
#   inflating: all_img/2008_007274.jpg
#   inflating: all_img/2008_007279.jpg
#   inflating: all_img/2008_007289.jpg
#   inflating: all_img/2008_007295.jpg
#   inflating: all_img/2008_007311.jpg
#   inflating: all_img/2008_007312.jpg
#   inflating: all_img/2008_007314.jpg
#   inflating: all_img/2008_007320.jpg
#   inflating: all_img/2008_007321.jpg
#   inflating: all_img/2008_007323.jpg
#   inflating: all_img/2008_007327.jpg
#   inflating: all_img/2008_007343.jpg
#   inflating: all_img/2008_007350.jpg
#   inflating: all_img/2008_007352.jpg
#   inflating: all_img/2008_007353.jpg
#   inflating: all_img/2008_007357.jpg
#   inflating: all_img/2008_007358.jpg
#   inflating: all_img/2008_007374.jpg
#   inflating: all_img/2008_007432.jpg
#   inflating: all_img/2008_007433.jpg
#   inflating: all_img/2008_007442.jpg
#   inflating: all_img/2008_007448.jpg
#   inflating: all_img/2008_007455.jpg
#   inflating: all_img/2008_007456.jpg
#   inflating: all_img/2008_007458.jpg
#   inflating: all_img/2008_007466.jpg
#   inflating: all_img/2008_007469.jpg
#   inflating: all_img/2008_007471.jpg
#   inflating: all_img/2008_007472.jpg
#   inflating: all_img/2008_007480.jpg
#   inflating: all_img/2008_007491.jpg
#   inflating: all_img/2008_007494.jpg
#   inflating: all_img/2008_007496.jpg
#   inflating: all_img/2008_007500.jpg
#   inflating: all_img/2008_007504.jpg
#   inflating: all_img/2008_007507.jpg
#   inflating: all_img/2008_007513.jpg
#   inflating: all_img/2008_007515.jpg
#   inflating: all_img/2008_007519.jpg
#   inflating: all_img/2008_007529.jpg
#   inflating: all_img/2008_007533.jpg
#   inflating: all_img/2008_007534.jpg
#   inflating: all_img/2008_007538.jpg
#   inflating: all_img/2008_007548.jpg
#   inflating: all_img/2008_007559.jpg
#   inflating: all_img/2008_007573.jpg
#   inflating: all_img/2008_007579.jpg
#   inflating: all_img/2008_007581.jpg
#   inflating: all_img/2008_007583.jpg
#   inflating: all_img/2008_007589.jpg
#   inflating: all_img/2008_007595.jpg
#   inflating: all_img/2008_007604.jpg
#   inflating: all_img/2008_007610.jpg
#   inflating: all_img/2008_007611.jpg
#   inflating: all_img/2008_007613.jpg
#   inflating: all_img/2008_007618.jpg
#   inflating: all_img/2008_007629.jpg
#   inflating: all_img/2008_007630.jpg
#   inflating: all_img/2008_007632.jpg
#   inflating: all_img/2008_007635.jpg
#   inflating: all_img/2008_007640.jpg
#   inflating: all_img/2008_007649.jpg
#   inflating: all_img/2008_007662.jpg
#   inflating: all_img/2008_007683.jpg
#   inflating: all_img/2008_007694.jpg
#   inflating: all_img/2008_007698.jpg
#   inflating: all_img/2008_007702.jpg
#   inflating: all_img/2008_007719.jpg
#   inflating: all_img/2008_007726.jpg
#   inflating: all_img/2008_007735.jpg
#   inflating: all_img/2008_007736.jpg
#   inflating: all_img/2008_007738.jpg
#   inflating: all_img/2008_007758.jpg
#   inflating: all_img/2008_007764.jpg
#   inflating: all_img/2008_007777.jpg
#   inflating: all_img/2008_007781.jpg
#   inflating: all_img/2008_007786.jpg
#   inflating: all_img/2008_007791.jpg
#   inflating: all_img/2008_007794.jpg
#   inflating: all_img/2008_007797.jpg
#   inflating: all_img/2008_007804.jpg
#   inflating: all_img/2008_007805.jpg
#   inflating: all_img/2008_007819.jpg
#   inflating: all_img/2008_007825.jpg
#   inflating: all_img/2008_007836.jpg
#   inflating: all_img/2008_007840.jpg
#   inflating: all_img/2008_007842.jpg
#   inflating: all_img/2008_007855.jpg
#   inflating: all_img/2008_007869.jpg
#   inflating: all_img/2008_007871.jpg
#   inflating: all_img/2008_007873.jpg
#   inflating: all_img/2008_007875.jpg
#   inflating: all_img/2008_007877.jpg
#   inflating: all_img/2008_007879.jpg
#   inflating: all_img/2008_007888.jpg
#   inflating: all_img/2008_007937.jpg
#   inflating: all_img/2008_007947.jpg
#   inflating: all_img/2008_007964.jpg
#   inflating: all_img/2008_007969.jpg
#   inflating: all_img/2008_007975.jpg
#   inflating: all_img/2008_007981.jpg
#   inflating: all_img/2008_007989.jpg
#   inflating: all_img/2008_007997.jpg
#   inflating: all_img/2008_008004.jpg
#   inflating: all_img/2008_008025.jpg
#   inflating: all_img/2008_008028.jpg
#   inflating: all_img/2008_008043.jpg
#   inflating: all_img/2008_008044.jpg
#   inflating: all_img/2008_008048.jpg
#   inflating: all_img/2008_008050.jpg
#   inflating: all_img/2008_008053.jpg
#   inflating: all_img/2008_008086.jpg
#   inflating: all_img/2008_008092.jpg
#   inflating: all_img/2008_008120.jpg
#   inflating: all_img/2008_008130.jpg
#   inflating: all_img/2008_008131.jpg
#   inflating: all_img/2008_008146.jpg
#   inflating: all_img/2008_008150.jpg
#   inflating: all_img/2008_008179.jpg
#   inflating: all_img/2008_008180.jpg
#   inflating: all_img/2008_008191.jpg
#   inflating: all_img/2008_008215.jpg
#   inflating: all_img/2008_008234.jpg
#   inflating: all_img/2008_008247.jpg
#   inflating: all_img/2008_008252.jpg
#   inflating: all_img/2008_008254.jpg
#   inflating: all_img/2008_008263.jpg
#   inflating: all_img/2008_008278.jpg
#   inflating: all_img/2008_008281.jpg
#   inflating: all_img/2008_008294.jpg
#   inflating: all_img/2008_008300.jpg
#   inflating: all_img/2008_008301.jpg
#   inflating: all_img/2008_008373.jpg
#   inflating: all_img/2008_008411.jpg
#   inflating: all_img/2008_008424.jpg
#   inflating: all_img/2008_008432.jpg
#   inflating: all_img/2008_008446.jpg
#   inflating: all_img/2008_008464.jpg
#   inflating: all_img/2008_008467.jpg
#   inflating: all_img/2008_008471.jpg
#   inflating: all_img/2008_008480.jpg
#   inflating: all_img/2008_008496.jpg
#   inflating: all_img/2008_008501.jpg
#   inflating: all_img/2008_008507.jpg
#   inflating: all_img/2008_008508.jpg
#   inflating: all_img/2008_008546.jpg
#   inflating: all_img/2008_008570.jpg
#   inflating: all_img/2008_008585.jpg
#   inflating: all_img/2008_008607.jpg
#   inflating: all_img/2008_008611.jpg
#   inflating: all_img/2008_008706.jpg
#   inflating: all_img/2008_008707.jpg
#   inflating: all_img/2008_008711.jpg
#   inflating: all_img/2008_008719.jpg
#   inflating: all_img/2008_008724.jpg
#   inflating: all_img/2008_008748.jpg
#   inflating: all_img/2008_008753.jpg
#   inflating: all_img/2008_008765.jpg
#   inflating: all_img/2009_000002.jpg
#   inflating: all_img/2009_000006.jpg
#   inflating: all_img/2009_000013.jpg
#   inflating: all_img/2009_000015.jpg
#   inflating: all_img/2009_000027.jpg
#   inflating: all_img/2009_000029.jpg
#   inflating: all_img/2009_000030.jpg
#   inflating: all_img/2009_000032.jpg
#   inflating: all_img/2009_000042.jpg
#   inflating: all_img/2009_000045.jpg
#   inflating: all_img/2009_000052.jpg
#   inflating: all_img/2009_000055.jpg
#   inflating: all_img/2009_000080.jpg
#   inflating: all_img/2009_000084.jpg
#   inflating: all_img/2009_000088.jpg
#   inflating: all_img/2009_000150.jpg
#   inflating: all_img/2009_000156.jpg
#   inflating: all_img/2009_000159.jpg
#   inflating: all_img/2009_000160.jpg
#   inflating: all_img/2009_000161.jpg
#   inflating: all_img/2009_000176.jpg
#   inflating: all_img/2009_000181.jpg
#   inflating: all_img/2009_000195.jpg
#   inflating: all_img/2009_000199.jpg
#   inflating: all_img/2009_000203.jpg
#   inflating: all_img/2009_000205.jpg
#   inflating: all_img/2009_000225.jpg
#   inflating: all_img/2009_000227.jpg
#   inflating: all_img/2009_000260.jpg
#   inflating: all_img/2009_000281.jpg
#   inflating: all_img/2009_000284.jpg
#   inflating: all_img/2009_000286.jpg
#   inflating: all_img/2009_000287.jpg
#   inflating: all_img/2009_000303.jpg
#   inflating: all_img/2009_000320.jpg
#   inflating: all_img/2009_000321.jpg
#   inflating: all_img/2009_000327.jpg
#   inflating: all_img/2009_000330.jpg
#   inflating: all_img/2009_000335.jpg
#   inflating: all_img/2009_000339.jpg
#   inflating: all_img/2009_000344.jpg
#   inflating: all_img/2009_000350.jpg
#   inflating: all_img/2009_000351.jpg
#   inflating: all_img/2009_000354.jpg
#   inflating: all_img/2009_000366.jpg
#   inflating: all_img/2009_000367.jpg
#   inflating: all_img/2009_000387.jpg
#   inflating: all_img/2009_000438.jpg
#   inflating: all_img/2009_000440.jpg
#   inflating: all_img/2009_000445.jpg
#   inflating: all_img/2009_000452.jpg
#   inflating: all_img/2009_000466.jpg
#   inflating: all_img/2009_000493.jpg
#   inflating: all_img/2009_000499.jpg
#   inflating: all_img/2009_000500.jpg
#   inflating: all_img/2009_000504.jpg
#   inflating: all_img/2009_000512.jpg
#   inflating: all_img/2009_000513.jpg
#   inflating: all_img/2009_000523.jpg
#   inflating: all_img/2009_000532.jpg
#   inflating: all_img/2009_000535.jpg
#   inflating: all_img/2009_000545.jpg
#   inflating: all_img/2009_000553.jpg
#   inflating: all_img/2009_000557.jpg
#   inflating: all_img/2009_000558.jpg
#   inflating: all_img/2009_000560.jpg
#   inflating: all_img/2009_000566.jpg
#   inflating: all_img/2009_000568.jpg
#   inflating: all_img/2009_000586.jpg
#   inflating: all_img/2009_000591.jpg
#   inflating: all_img/2009_000593.jpg
#   inflating: all_img/2009_000599.jpg
#   inflating: all_img/2009_000600.jpg
#   inflating: all_img/2009_000614.jpg
#   inflating: all_img/2009_000625.jpg
#   inflating: all_img/2009_000631.jpg
#   inflating: all_img/2009_000634.jpg
#   inflating: all_img/2009_000636.jpg
#   inflating: all_img/2009_000638.jpg
#   inflating: all_img/2009_000647.jpg
#   inflating: all_img/2009_000648.jpg
#   inflating: all_img/2009_000651.jpg
#   inflating: all_img/2009_000662.jpg
#   inflating: all_img/2009_000681.jpg
#   inflating: all_img/2009_000684.jpg
#   inflating: all_img/2009_000695.jpg
#   inflating: all_img/2009_000696.jpg
#   inflating: all_img/2009_000702.jpg
#   inflating: all_img/2009_000737.jpg
#   inflating: all_img/2009_000745.jpg
#   inflating: all_img/2009_000756.jpg
#   inflating: all_img/2009_000770.jpg
#   inflating: all_img/2009_000774.jpg
#   inflating: all_img/2009_000778.jpg
#   inflating: all_img/2009_000782.jpg
#   inflating: all_img/2009_000796.jpg
#   inflating: all_img/2009_000801.jpg
#   inflating: all_img/2009_000804.jpg
#   inflating: all_img/2009_000805.jpg
#   inflating: all_img/2009_000817.jpg
#   inflating: all_img/2009_000839.jpg
#   inflating: all_img/2009_000854.jpg
#   inflating: all_img/2009_000862.jpg
#   inflating: all_img/2009_000869.jpg
#   inflating: all_img/2009_000871.jpg
#   inflating: all_img/2009_000874.jpg
#   inflating: all_img/2009_000886.jpg
#   inflating: all_img/2009_000887.jpg
#   inflating: all_img/2009_000892.jpg
#   inflating: all_img/2009_000906.jpg
#   inflating: all_img/2009_000909.jpg
#   inflating: all_img/2009_000923.jpg
#   inflating: all_img/2009_000935.jpg
#   inflating: all_img/2009_000945.jpg
#   inflating: all_img/2009_000948.jpg
#   inflating: all_img/2009_000953.jpg
#   inflating: all_img/2009_000954.jpg
#   inflating: all_img/2009_000955.jpg
#   inflating: all_img/2009_000964.jpg
#   inflating: all_img/2009_000966.jpg
#   inflating: all_img/2009_000967.jpg
#   inflating: all_img/2009_000970.jpg
#   inflating: all_img/2009_000975.jpg
#   inflating: all_img/2009_000979.jpg
#   inflating: all_img/2009_000985.jpg
#   inflating: all_img/2009_000989.jpg
#   inflating: all_img/2009_001006.jpg
#   inflating: all_img/2009_001008.jpg
#   inflating: all_img/2009_001016.jpg
#   inflating: all_img/2009_001027.jpg
#   inflating: all_img/2009_001037.jpg
#   inflating: all_img/2009_001044.jpg
#   inflating: all_img/2009_001052.jpg
#   inflating: all_img/2009_001056.jpg
#   inflating: all_img/2009_001066.jpg
#   inflating: all_img/2009_001113.jpg
#   inflating: all_img/2009_001117.jpg
#   inflating: all_img/2009_001124.jpg
#   inflating: all_img/2009_001126.jpg
#   inflating: all_img/2009_001129.jpg
#   inflating: all_img/2009_001138.jpg
#   inflating: all_img/2009_001139.jpg
#   inflating: all_img/2009_001153.jpg
#   inflating: all_img/2009_001159.jpg
#   inflating: all_img/2009_001194.jpg
#   inflating: all_img/2009_001195.jpg
#   inflating: all_img/2009_001197.jpg
#   inflating: all_img/2009_001198.jpg
#   inflating: all_img/2009_001201.jpg
#   inflating: all_img/2009_001205.jpg
#   inflating: all_img/2009_001216.jpg
#   inflating: all_img/2009_001225.jpg
#   inflating: all_img/2009_001227.jpg
#   inflating: all_img/2009_001240.jpg
#   inflating: all_img/2009_001251.jpg
#   inflating: all_img/2009_001255.jpg
#   inflating: all_img/2009_001260.jpg
#   inflating: all_img/2009_001270.jpg
#   inflating: all_img/2009_001271.jpg
#   inflating: all_img/2009_001279.jpg
#   inflating: all_img/2009_001288.jpg
#   inflating: all_img/2009_001305.jpg
#   inflating: all_img/2009_001306.jpg
#   inflating: all_img/2009_001312.jpg
#   inflating: all_img/2009_001316.jpg
#   inflating: all_img/2009_001321.jpg
#   inflating: all_img/2009_001329.jpg
#   inflating: all_img/2009_001332.jpg
#   inflating: all_img/2009_001344.jpg
#   inflating: all_img/2009_001361.jpg
#   inflating: all_img/2009_001364.jpg
#   inflating: all_img/2009_001366.jpg
#   inflating: all_img/2009_001367.jpg
#   inflating: all_img/2009_001368.jpg
#   inflating: all_img/2009_001369.jpg
#   inflating: all_img/2009_001372.jpg
#   inflating: all_img/2009_001374.jpg
#   inflating: all_img/2009_001387.jpg
#   inflating: all_img/2009_001388.jpg
#   inflating: all_img/2009_001390.jpg
#   inflating: all_img/2009_001391.jpg
#   inflating: all_img/2009_001456.jpg
#   inflating: all_img/2009_001472.jpg
#   inflating: all_img/2009_001476.jpg
#   inflating: all_img/2009_001481.jpg
#   inflating: all_img/2009_001484.jpg
#   inflating: all_img/2009_001498.jpg
#   inflating: all_img/2009_001501.jpg
#   inflating: all_img/2009_001502.jpg
#   inflating: all_img/2009_001517.jpg
#   inflating: all_img/2009_001522.jpg
#   inflating: all_img/2009_001535.jpg
#   inflating: all_img/2009_001536.jpg
#   inflating: all_img/2009_001538.jpg
#   inflating: all_img/2009_001541.jpg
#   inflating: all_img/2009_001549.jpg
#   inflating: all_img/2009_001550.jpg
#   inflating: all_img/2009_001558.jpg
#   inflating: all_img/2009_001562.jpg
#   inflating: all_img/2009_001568.jpg
#   inflating: all_img/2009_001589.jpg
#   inflating: all_img/2009_001591.jpg
#   inflating: all_img/2009_001595.jpg
#   inflating: all_img/2009_001606.jpg
#   inflating: all_img/2009_001612.jpg
#   inflating: all_img/2009_001633.jpg
#   inflating: all_img/2009_001674.jpg
#   inflating: all_img/2009_001675.jpg
#   inflating: all_img/2009_001678.jpg
#   inflating: all_img/2009_001689.jpg
#   inflating: all_img/2009_001706.jpg
#   inflating: all_img/2009_001713.jpg
#   inflating: all_img/2009_001733.jpg
#   inflating: all_img/2009_001744.jpg
#   inflating: all_img/2009_001752.jpg
#   inflating: all_img/2009_001780.jpg
#   inflating: all_img/2009_001781.jpg
#   inflating: all_img/2009_001782.jpg
#   inflating: all_img/2009_001792.jpg
#   inflating: all_img/2009_001811.jpg
#   inflating: all_img/2009_001816.jpg
#   inflating: all_img/2009_001820.jpg
#   inflating: all_img/2009_001828.jpg
#   inflating: all_img/2009_001830.jpg
#   inflating: all_img/2009_001869.jpg
#   inflating: all_img/2009_001881.jpg
#   inflating: all_img/2009_001884.jpg
#   inflating: all_img/2009_001894.jpg
#   inflating: all_img/2009_001898.jpg
#   inflating: all_img/2009_001902.jpg
#   inflating: all_img/2009_001905.jpg
#   inflating: all_img/2009_001910.jpg
#   inflating: all_img/2009_001915.jpg
#   inflating: all_img/2009_001916.jpg
#   inflating: all_img/2009_001917.jpg
#   inflating: all_img/2009_001926.jpg
#   inflating: all_img/2009_001927.jpg
#   inflating: all_img/2009_001931.jpg
#   inflating: all_img/2009_001948.jpg
#   inflating: all_img/2009_001962.jpg
#   inflating: all_img/2009_002000.jpg
#   inflating: all_img/2009_002008.jpg
#   inflating: all_img/2009_002011.jpg
#   inflating: all_img/2009_002012.jpg
#   inflating: all_img/2009_002018.jpg
#   inflating: all_img/2009_002031.jpg
#   inflating: all_img/2009_002039.jpg
#   inflating: all_img/2009_002047.jpg
#   inflating: all_img/2009_002052.jpg
#   inflating: all_img/2009_002053.jpg
#   inflating: all_img/2009_002061.jpg
#   inflating: all_img/2009_002073.jpg
#   inflating: all_img/2009_002087.jpg
#   inflating: all_img/2009_002093.jpg
#   inflating: all_img/2009_002099.jpg
#   inflating: all_img/2009_002103.jpg
#   inflating: all_img/2009_002104.jpg
#   inflating: all_img/2009_002117.jpg
#   inflating: all_img/2009_002119.jpg
#   inflating: all_img/2009_002120.jpg
#   inflating: all_img/2009_002141.jpg
#   inflating: all_img/2009_002149.jpg
#   inflating: all_img/2009_002155.jpg
#   inflating: all_img/2009_002164.jpg
#   inflating: all_img/2009_002176.jpg
#   inflating: all_img/2009_002254.jpg
#   inflating: all_img/2009_002258.jpg
#   inflating: all_img/2009_002259.jpg
#   inflating: all_img/2009_002267.jpg
#   inflating: all_img/2009_002268.jpg
#   inflating: all_img/2009_002271.jpg
#   inflating: all_img/2009_002272.jpg
#   inflating: all_img/2009_002295.jpg
#   inflating: all_img/2009_002299.jpg
#   inflating: all_img/2009_002302.jpg
#   inflating: all_img/2009_002311.jpg
#   inflating: all_img/2009_002314.jpg
#   inflating: all_img/2009_002320.jpg
#   inflating: all_img/2009_002324.jpg
#   inflating: all_img/2009_002348.jpg
#   inflating: all_img/2009_002352.jpg
#   inflating: all_img/2009_002363.jpg
#   inflating: all_img/2009_002371.jpg
#   inflating: all_img/2009_002373.jpg
#   inflating: all_img/2009_002380.jpg
#   inflating: all_img/2009_002387.jpg
#   inflating: all_img/2009_002388.jpg
#   inflating: all_img/2009_002400.jpg
#   inflating: all_img/2009_002419.jpg
#   inflating: all_img/2009_002424.jpg
#   inflating: all_img/2009_002429.jpg
#   inflating: all_img/2009_002432.jpg
#   inflating: all_img/2009_002488.jpg
#   inflating: all_img/2009_002499.jpg
#   inflating: all_img/2009_002505.jpg
#   inflating: all_img/2009_002517.jpg
#   inflating: all_img/2009_002519.jpg
#   inflating: all_img/2009_002527.jpg
#   inflating: all_img/2009_002532.jpg
#   inflating: all_img/2009_002535.jpg
#   inflating: all_img/2009_002539.jpg
#   inflating: all_img/2009_002553.jpg
#   inflating: all_img/2009_002561.jpg
#   inflating: all_img/2009_002563.jpg
#   inflating: all_img/2009_002570.jpg
#   inflating: all_img/2009_002592.jpg
#   inflating: all_img/2009_002599.jpg
#   inflating: all_img/2009_002605.jpg
#   inflating: all_img/2009_002609.jpg
#   inflating: all_img/2009_002614.jpg
#   inflating: all_img/2009_002615.jpg
#   inflating: all_img/2009_002618.jpg
#   inflating: all_img/2009_002626.jpg
#   inflating: all_img/2009_002632.jpg
#   inflating: all_img/2009_002667.jpg
#   inflating: all_img/2009_002668.jpg
#   inflating: all_img/2009_002672.jpg
#   inflating: all_img/2009_002674.jpg
#   inflating: all_img/2009_002680.jpg
#   inflating: all_img/2009_002687.jpg
#   inflating: all_img/2009_002704.jpg
#   inflating: all_img/2009_002714.jpg
#   inflating: all_img/2009_002728.jpg
#   inflating: all_img/2009_002739.jpg
#   inflating: all_img/2009_002753.jpg
#   inflating: all_img/2009_002803.jpg
#   inflating: all_img/2009_002808.jpg
#   inflating: all_img/2009_002813.jpg
#   inflating: all_img/2009_002833.jpg
#   inflating: all_img/2009_002835.jpg
#   inflating: all_img/2009_002836.jpg
#   inflating: all_img/2009_002837.jpg
#   inflating: all_img/2009_002843.jpg
#   inflating: all_img/2009_002845.jpg
#   inflating: all_img/2009_002847.jpg
#   inflating: all_img/2009_002853.jpg
#   inflating: all_img/2009_002855.jpg
#   inflating: all_img/2009_002862.jpg
#   inflating: all_img/2009_002865.jpg
#   inflating: all_img/2009_002876.jpg
#   inflating: all_img/2009_002888.jpg
#   inflating: all_img/2009_002898.jpg
#   inflating: all_img/2009_002908.jpg
#   inflating: all_img/2009_002910.jpg
#   inflating: all_img/2009_002914.jpg
#   inflating: all_img/2009_002917.jpg
#   inflating: all_img/2009_002933.jpg
#   inflating: all_img/2009_002936.jpg
#   inflating: all_img/2009_002941.jpg
#   inflating: all_img/2009_002955.jpg
#   inflating: all_img/2009_002958.jpg
#   inflating: all_img/2009_002971.jpg
#   inflating: all_img/2009_002985.jpg
#   inflating: all_img/2009_002990.jpg
#   inflating: all_img/2009_002999.jpg
#   inflating: all_img/2009_003005.jpg
#   inflating: all_img/2009_003007.jpg
#   inflating: all_img/2009_003013.jpg
#   inflating: all_img/2009_003018.jpg
#   inflating: all_img/2009_003023.jpg
#   inflating: all_img/2009_003031.jpg
#   inflating: all_img/2009_003033.jpg
#   inflating: all_img/2009_003053.jpg
#   inflating: all_img/2009_003056.jpg
#   inflating: all_img/2009_003063.jpg
#   inflating: all_img/2009_003066.jpg
#   inflating: all_img/2009_003067.jpg
#   inflating: all_img/2009_003070.jpg
#   inflating: all_img/2009_003075.jpg
#   inflating: all_img/2009_003091.jpg
#   inflating: all_img/2009_003095.jpg
#   inflating: all_img/2009_003097.jpg
#   inflating: all_img/2009_003107.jpg
#   inflating: all_img/2009_003108.jpg
#   inflating: all_img/2009_003118.jpg
#   inflating: all_img/2009_003122.jpg
#   inflating: all_img/2009_003130.jpg
#   inflating: all_img/2009_003132.jpg
#   inflating: all_img/2009_003138.jpg
#   inflating: all_img/2009_003143.jpg
#   inflating: all_img/2009_003222.jpg
#   inflating: all_img/2009_003224.jpg
#   inflating: all_img/2009_003225.jpg
#   inflating: all_img/2009_003241.jpg
#   inflating: all_img/2009_003267.jpg
#   inflating: all_img/2009_003277.jpg
#   inflating: all_img/2009_003278.jpg
#   inflating: all_img/2009_003304.jpg
#   inflating: all_img/2009_003309.jpg
#   inflating: all_img/2009_003343.jpg
#   inflating: all_img/2009_003360.jpg
#   inflating: all_img/2009_003369.jpg
#   inflating: all_img/2009_003372.jpg
#   inflating: all_img/2009_003375.jpg
#   inflating: all_img/2009_003376.jpg
#   inflating: all_img/2009_003380.jpg
#   inflating: all_img/2009_003381.jpg
#   inflating: all_img/2009_003386.jpg
#   inflating: all_img/2009_003395.jpg
#   inflating: all_img/2009_003396.jpg
#   inflating: all_img/2009_003402.jpg
#   inflating: all_img/2009_003406.jpg
#   inflating: all_img/2009_003419.jpg
#   inflating: all_img/2009_003456.jpg
#   inflating: all_img/2009_003457.jpg
#   inflating: all_img/2009_003458.jpg
#   inflating: all_img/2009_003461.jpg
#   inflating: all_img/2009_003466.jpg
#   inflating: all_img/2009_003467.jpg
#   inflating: all_img/2009_003469.jpg
#   inflating: all_img/2009_003489.jpg
#   inflating: all_img/2009_003500.jpg
#   inflating: all_img/2009_003513.jpg
#   inflating: all_img/2009_003524.jpg
#   inflating: all_img/2009_003571.jpg
#   inflating: all_img/2009_003589.jpg
#   inflating: all_img/2009_003601.jpg
#   inflating: all_img/2009_003608.jpg
#   inflating: all_img/2009_003612.jpg
#   inflating: all_img/2009_003626.jpg
#   inflating: all_img/2009_003635.jpg
#   inflating: all_img/2009_003644.jpg
#   inflating: all_img/2009_003647.jpg
#   inflating: all_img/2009_003655.jpg
#   inflating: all_img/2009_003657.jpg
#   inflating: all_img/2009_003660.jpg
#   inflating: all_img/2009_003663.jpg
#   inflating: all_img/2009_003667.jpg
#   inflating: all_img/2009_003696.jpg
#   inflating: all_img/2009_003698.jpg
#   inflating: all_img/2009_003703.jpg
#   inflating: all_img/2009_003704.jpg
#   inflating: all_img/2009_003708.jpg
#   inflating: all_img/2009_003709.jpg
#   inflating: all_img/2009_003714.jpg
#   inflating: all_img/2009_003781.jpg
#   inflating: all_img/2009_003783.jpg
#   inflating: all_img/2009_003786.jpg
#   inflating: all_img/2009_003799.jpg
#   inflating: all_img/2009_003801.jpg
#   inflating: all_img/2009_003805.jpg
#   inflating: all_img/2009_003806.jpg
#   inflating: all_img/2009_003810.jpg
#   inflating: all_img/2009_003814.jpg
#   inflating: all_img/2009_003827.jpg
#   inflating: all_img/2009_003832.jpg
#   inflating: all_img/2009_003838.jpg
#   inflating: all_img/2009_003847.jpg
#   inflating: all_img/2009_003860.jpg
#   inflating: all_img/2009_003867.jpg
#   inflating: all_img/2009_003879.jpg
#   inflating: all_img/2009_003883.jpg
#   inflating: all_img/2009_003902.jpg
#   inflating: all_img/2009_003904.jpg
#   inflating: all_img/2009_003913.jpg
#   inflating: all_img/2009_003916.jpg
#   inflating: all_img/2009_003928.jpg
#   inflating: all_img/2009_003947.jpg
#   inflating: all_img/2009_003955.jpg
#   inflating: all_img/2009_003969.jpg
#   inflating: all_img/2009_003971.jpg
#   inflating: all_img/2009_003974.jpg
#   inflating: all_img/2009_003977.jpg
#   inflating: all_img/2009_003985.jpg
#   inflating: all_img/2009_003992.jpg
#   inflating: all_img/2009_003994.jpg
#   inflating: all_img/2009_004012.jpg
#   inflating: all_img/2009_004016.jpg
#   inflating: all_img/2009_004022.jpg
#   inflating: all_img/2009_004033.jpg
#   inflating: all_img/2009_004037.jpg
#   inflating: all_img/2009_004038.jpg
#   inflating: all_img/2009_004082.jpg
#   inflating: all_img/2009_004083.jpg
#   inflating: all_img/2009_004096.jpg
#   inflating: all_img/2009_004108.jpg
#   inflating: all_img/2009_004111.jpg
#   inflating: all_img/2009_004121.jpg
#   inflating: all_img/2009_004139.jpg
#   inflating: all_img/2009_004150.jpg
#   inflating: all_img/2009_004153.jpg
#   inflating: all_img/2009_004157.jpg
#   inflating: all_img/2009_004183.jpg
#   inflating: all_img/2009_004197.jpg
#   inflating: all_img/2009_004200.jpg
#   inflating: all_img/2009_004203.jpg
#   inflating: all_img/2009_004210.jpg
#   inflating: all_img/2009_004225.jpg
#   inflating: all_img/2009_004231.jpg
#   inflating: all_img/2009_004232.jpg
#   inflating: all_img/2009_004234.jpg
#   inflating: all_img/2009_004242.jpg
#   inflating: all_img/2009_004248.jpg
#   inflating: all_img/2009_004261.jpg
#   inflating: all_img/2009_004271.jpg
#   inflating: all_img/2009_004272.jpg
#   inflating: all_img/2009_004277.jpg
#   inflating: all_img/2009_004295.jpg
#   inflating: all_img/2009_004307.jpg
#   inflating: all_img/2009_004308.jpg
#   inflating: all_img/2009_004317.jpg
#   inflating: all_img/2009_004319.jpg
#   inflating: all_img/2009_004358.jpg
#   inflating: all_img/2009_004361.jpg
#   inflating: all_img/2009_004364.jpg
#   inflating: all_img/2009_004370.jpg
#   inflating: all_img/2009_004374.jpg
#   inflating: all_img/2009_004382.jpg
#   inflating: all_img/2009_004383.jpg
#   inflating: all_img/2009_004390.jpg
#   inflating: all_img/2009_004392.jpg
#   inflating: all_img/2009_004402.jpg
#   inflating: all_img/2009_004409.jpg
#   inflating: all_img/2009_004411.jpg
#   inflating: all_img/2009_004414.jpg
#   inflating: all_img/2009_004417.jpg
#   inflating: all_img/2009_004424.jpg
#   inflating: all_img/2009_004425.jpg
#   inflating: all_img/2009_004434.jpg
#   inflating: all_img/2009_004436.jpg
#   inflating: all_img/2009_004440.jpg
#   inflating: all_img/2009_004442.jpg
#   inflating: all_img/2009_004444.jpg
#   inflating: all_img/2009_004448.jpg
#   inflating: all_img/2009_004465.jpg
#   inflating: all_img/2009_004471.jpg
#   inflating: all_img/2009_004475.jpg
#   inflating: all_img/2009_004477.jpg
#   inflating: all_img/2009_004483.jpg
#   inflating: all_img/2009_004492.jpg
#   inflating: all_img/2009_004494.jpg
#   inflating: all_img/2009_004496.jpg
#   inflating: all_img/2009_004504.jpg
#   inflating: all_img/2009_004529.jpg
#   inflating: all_img/2009_004535.jpg
#   inflating: all_img/2009_004545.jpg
#   inflating: all_img/2009_004567.jpg
#   inflating: all_img/2009_004571.jpg
#   inflating: all_img/2009_004572.jpg
#   inflating: all_img/2009_004581.jpg
#   inflating: all_img/2009_004590.jpg
#   inflating: all_img/2009_004592.jpg
#   inflating: all_img/2009_004594.jpg
#   inflating: all_img/2009_004598.jpg
#   inflating: all_img/2009_004601.jpg
#   inflating: all_img/2009_004607.jpg
#   inflating: all_img/2009_004614.jpg
#   inflating: all_img/2009_004620.jpg
#   inflating: all_img/2009_004683.jpg
#   inflating: all_img/2009_004684.jpg
#   inflating: all_img/2009_004688.jpg
#   inflating: all_img/2009_004705.jpg
#   inflating: all_img/2009_004709.jpg
#   inflating: all_img/2009_004716.jpg
#   inflating: all_img/2009_004721.jpg
#   inflating: all_img/2009_004728.jpg
#   inflating: all_img/2009_004732.jpg
#   inflating: all_img/2009_004744.jpg
#   inflating: all_img/2009_004779.jpg
#   inflating: all_img/2009_004789.jpg
#   inflating: all_img/2009_004796.jpg
#   inflating: all_img/2009_004797.jpg
#   inflating: all_img/2009_004813.jpg
#   inflating: all_img/2009_004820.jpg
#   inflating: all_img/2009_004824.jpg
#   inflating: all_img/2009_004828.jpg
#   inflating: all_img/2009_004829.jpg
#   inflating: all_img/2009_004841.jpg
#   inflating: all_img/2009_004846.jpg
#   inflating: all_img/2009_004855.jpg
#   inflating: all_img/2009_004867.jpg
#   inflating: all_img/2009_004871.jpg
#   inflating: all_img/2009_004872.jpg
#   inflating: all_img/2009_004876.jpg
#   inflating: all_img/2009_004877.jpg
#   inflating: all_img/2009_004882.jpg
#   inflating: all_img/2009_004887.jpg
#   inflating: all_img/2009_004889.jpg
#   inflating: all_img/2009_004903.jpg
#   inflating: all_img/2009_004969.jpg
#   inflating: all_img/2009_004971.jpg
#   inflating: all_img/2009_004972.jpg
#   inflating: all_img/2009_004980.jpg
#   inflating: all_img/2009_004986.jpg
#   inflating: all_img/2009_004999.jpg
#   inflating: all_img/2009_005019.jpg
#   inflating: all_img/2009_005031.jpg
#   inflating: all_img/2009_005033.jpg
#   inflating: all_img/2009_005036.jpg
#   inflating: all_img/2009_005037.jpg
#   inflating: all_img/2009_005051.jpg
#   inflating: all_img/2009_005055.jpg
#   inflating: all_img/2009_005060.jpg
#   inflating: all_img/2009_005064.jpg
#   inflating: all_img/2009_005073.jpg
#   inflating: all_img/2009_005075.jpg
#   inflating: all_img/2009_005083.jpg
#   inflating: all_img/2009_005095.jpg
#   inflating: all_img/2009_005102.jpg
#   inflating: all_img/2009_005104.jpg
#   inflating: all_img/2009_005107.jpg
#   inflating: all_img/2009_005111.jpg
#   inflating: all_img/2009_005119.jpg
#   inflating: all_img/2009_005120.jpg
#   inflating: all_img/2009_005127.jpg
#   inflating: all_img/2009_005133.jpg
#   inflating: all_img/2009_005142.jpg
#   inflating: all_img/2009_005144.jpg
#   inflating: all_img/2009_005153.jpg
#   inflating: all_img/2009_005154.jpg
#   inflating: all_img/2009_005156.jpg
#   inflating: all_img/2009_005158.jpg
#   inflating: all_img/2009_005160.jpg
#   inflating: all_img/2009_005162.jpg
#   inflating: all_img/2009_005177.jpg
#   inflating: all_img/2009_005178.jpg
#   inflating: all_img/2009_005189.jpg
#   inflating: all_img/2009_005225.jpg
#   inflating: all_img/2009_005231.jpg
#   inflating: all_img/2009_005232.jpg
#   inflating: all_img/2009_005236.jpg
#   inflating: all_img/2009_005251.jpg
#   inflating: all_img/2009_005272.jpg
#   inflating: all_img/2009_005293.jpg
#   inflating: all_img/2009_005294.jpg
#   inflating: all_img/2010_000009.jpg
#   inflating: all_img/2010_000014.jpg
#   inflating: all_img/2010_000026.jpg
#   inflating: all_img/2010_000031.jpg
#   inflating: all_img/2010_000033.jpg
#   inflating: all_img/2010_000036.jpg
#   inflating: all_img/2010_000043.jpg
#   inflating: all_img/2010_000045.jpg
#   inflating: all_img/2010_000048.jpg
#   inflating: all_img/2010_000054.jpg
#   inflating: all_img/2010_000056.jpg
#   inflating: all_img/2010_000061.jpg
#   inflating: all_img/2010_000065.jpg
#   inflating: all_img/2010_000067.jpg
#   inflating: all_img/2010_000069.jpg
#   inflating: all_img/2010_000072.jpg
#   inflating: all_img/2010_000073.jpg
#   inflating: all_img/2010_000079.jpg
#   inflating: all_img/2010_000082.jpg
#   inflating: all_img/2010_000091.jpg
#   inflating: all_img/2010_000098.jpg
#   inflating: all_img/2010_000099.jpg
#   inflating: all_img/2010_000109.jpg
#   inflating: all_img/2010_000110.jpg
#   inflating: all_img/2010_000111.jpg
#   inflating: all_img/2010_000113.jpg
#   inflating: all_img/2010_000114.jpg
#   inflating: all_img/2010_000118.jpg
#   inflating: all_img/2010_000124.jpg
#   inflating: all_img/2010_000127.jpg
#   inflating: all_img/2010_000152.jpg
#   inflating: all_img/2010_000157.jpg
#   inflating: all_img/2010_000159.jpg
#   inflating: all_img/2010_000160.jpg
#   inflating: all_img/2010_000163.jpg
#   inflating: all_img/2010_000165.jpg
#   inflating: all_img/2010_000170.jpg
#   inflating: all_img/2010_000172.jpg
#   inflating: all_img/2010_000175.jpg
#   inflating: all_img/2010_000182.jpg
#   inflating: all_img/2010_000183.jpg
#   inflating: all_img/2010_000194.jpg
#   inflating: all_img/2010_000198.jpg
#   inflating: all_img/2010_000203.jpg
#   inflating: all_img/2010_000209.jpg
#   inflating: all_img/2010_000216.jpg
#   inflating: all_img/2010_000218.jpg
#   inflating: all_img/2010_000229.jpg
#   inflating: all_img/2010_000244.jpg
#   inflating: all_img/2010_000246.jpg
#   inflating: all_img/2010_000247.jpg
#   inflating: all_img/2010_000248.jpg
#   inflating: all_img/2010_000250.jpg
#   inflating: all_img/2010_000254.jpg
#   inflating: all_img/2010_000260.jpg
#   inflating: all_img/2010_000261.jpg
#   inflating: all_img/2010_000263.jpg
# ...
#   inflating: Generate_dataset/images/007405.jpg
#   inflating: Generate_dataset/images/007409.jpg
#   inflating: Generate_dataset/images/007418.jpg
#   inflating: Generate_dataset/images/007434.jpg
#   inflating: Generate_dataset/images/007441.jpg
#   inflating: Generate_dataset/images/007459.jpg
#   inflating: Generate_dataset/images/007463.jpg
#   inflating: Generate_dataset/images/007478.jpg
#   inflating: Generate_dataset/images/007487.jpg
#   inflating: Generate_dataset/images/007495.jpg
#   inflating: Generate_dataset/images/007502.jpg
#   inflating: Generate_dataset/images/007507.jpg
#   inflating: Generate_dataset/images/007510.jpg
#   inflating: Generate_dataset/images/007515.jpg
#   inflating: Generate_dataset/images/007529.jpg
#   inflating: Generate_dataset/images/007541.jpg
#   inflating: Generate_dataset/images/007542.jpg
#   inflating: Generate_dataset/images/007548.jpg
#   inflating: Generate_dataset/images/007556.jpg
#   inflating: Generate_dataset/images/007560.jpg
#   inflating: Generate_dataset/images/007562.jpg
#   inflating: Generate_dataset/images/007574.jpg
#   inflating: Generate_dataset/images/007588.jpg
#   inflating: Generate_dataset/images/007607.jpg
#   inflating: Generate_dataset/images/007613.jpg
#   inflating: Generate_dataset/images/007617.jpg
#   inflating: Generate_dataset/images/007632.jpg
#   inflating: Generate_dataset/images/007638.jpg
#   inflating: Generate_dataset/images/007659.jpg
#   inflating: Generate_dataset/images/007665.jpg
#   inflating: Generate_dataset/images/007674.jpg
#   inflating: Generate_dataset/images/007693.jpg
#   inflating: Generate_dataset/images/007698.jpg
#   inflating: Generate_dataset/images/007701.jpg
#   inflating: Generate_dataset/images/007703.jpg
#   inflating: Generate_dataset/images/007710.jpg
#   inflating: Generate_dataset/images/007711.jpg
#   inflating: Generate_dataset/images/007716.jpg
#   inflating: Generate_dataset/images/007733.jpg
#   inflating: Generate_dataset/images/007734.jpg
#   inflating: Generate_dataset/images/007757.jpg
#   inflating: Generate_dataset/images/007787.jpg
#   inflating: Generate_dataset/images/007794.jpg
#   inflating: Generate_dataset/images/007800.jpg
#   inflating: Generate_dataset/images/007802.jpg
#   inflating: Generate_dataset/images/007806.jpg
#   inflating: Generate_dataset/images/007807.jpg
#   inflating: Generate_dataset/images/007818.jpg
#   inflating: Generate_dataset/images/007823.jpg
#   inflating: Generate_dataset/images/007825.jpg
#   inflating: Generate_dataset/images/007827.jpg
#   inflating: Generate_dataset/images/007829.jpg
#   inflating: Generate_dataset/images/007837.jpg
#   inflating: Generate_dataset/images/007844.jpg
#   inflating: Generate_dataset/images/007866.jpg
#   inflating: Generate_dataset/images/007867.jpg
#   inflating: Generate_dataset/images/007875.jpg
#   inflating: Generate_dataset/images/007880.jpg
#   inflating: Generate_dataset/images/007907.jpg
#   inflating: Generate_dataset/images/007918.jpg
#   inflating: Generate_dataset/images/007930.jpg
#   inflating: Generate_dataset/images/007937.jpg
#   inflating: Generate_dataset/images/007938.jpg
#   inflating: Generate_dataset/images/007944.jpg
#   inflating: Generate_dataset/images/007948.jpg
#   inflating: Generate_dataset/images/007949.jpg
#   inflating: Generate_dataset/images/007960.jpg
#   inflating: Generate_dataset/images/007973.jpg
#   inflating: Generate_dataset/images/007993.jpg
#   inflating: Generate_dataset/images/007995.jpg
#   inflating: Generate_dataset/images/008006.jpg
#   inflating: Generate_dataset/images/008007.jpg
#   inflating: Generate_dataset/images/008011.jpg
#   inflating: Generate_dataset/images/008016.jpg
#   inflating: Generate_dataset/images/008020.jpg
#   inflating: Generate_dataset/images/008025.jpg
#   inflating: Generate_dataset/images/008030.jpg
#   inflating: Generate_dataset/images/008054.jpg
#   inflating: Generate_dataset/images/008088.jpg
#   inflating: Generate_dataset/images/008129.jpg
#   inflating: Generate_dataset/images/008133.jpg
#   inflating: Generate_dataset/images/008135.jpg
#   inflating: Generate_dataset/images/008136.jpg
#   inflating: Generate_dataset/images/008143.jpg
#   inflating: Generate_dataset/images/008149.jpg
#   inflating: Generate_dataset/images/008158.jpg
#   inflating: Generate_dataset/images/008161.jpg
#   inflating: Generate_dataset/images/008176.jpg
#   inflating: Generate_dataset/images/008181.jpg
#   inflating: Generate_dataset/images/008182.jpg
#   inflating: Generate_dataset/images/008201.jpg
#   inflating: Generate_dataset/images/008212.jpg
#   inflating: Generate_dataset/images/008221.jpg
#   inflating: Generate_dataset/images/008240.jpg
#   inflating: Generate_dataset/images/008246.jpg
#   inflating: Generate_dataset/images/008267.jpg
#   inflating: Generate_dataset/images/008270.jpg
#   inflating: Generate_dataset/images/008283.jpg
#   inflating: Generate_dataset/images/008289.jpg
#   inflating: Generate_dataset/images/008290.jpg
#   inflating: Generate_dataset/images/008328.jpg
#   inflating: Generate_dataset/images/008337.jpg
#   inflating: Generate_dataset/images/008340.jpg
#   inflating: Generate_dataset/images/008352.jpg
#   inflating: Generate_dataset/images/008353.jpg
#   inflating: Generate_dataset/images/008356.jpg
#   inflating: Generate_dataset/images/008357.jpg
#   inflating: Generate_dataset/images/008361.jpg
#   inflating: Generate_dataset/images/008366.jpg
#   inflating: Generate_dataset/images/008375.jpg
#   inflating: Generate_dataset/images/008378.jpg
#   inflating: Generate_dataset/images/008406.jpg
#   inflating: Generate_dataset/images/008408.jpg
#   inflating: Generate_dataset/images/008419.jpg
#   inflating: Generate_dataset/images/008420.jpg
#   inflating: Generate_dataset/images/008421.jpg
#   inflating: Generate_dataset/images/008432.jpg
#   inflating: Generate_dataset/images/008440.jpg
#   inflating: Generate_dataset/images/008441.jpg
#   inflating: Generate_dataset/images/008447.jpg
#   inflating: Generate_dataset/images/008448.jpg
#   inflating: Generate_dataset/images/008459.jpg
#   inflating: Generate_dataset/images/008464.jpg
#   inflating: Generate_dataset/images/008479.jpg
#   inflating: Generate_dataset/images/008488.jpg
#   inflating: Generate_dataset/images/008489.jpg
#   inflating: Generate_dataset/images/008497.jpg
#   inflating: Generate_dataset/images/008504.jpg
#   inflating: Generate_dataset/images/008507.jpg
#   inflating: Generate_dataset/images/008511.jpg
#   inflating: Generate_dataset/images/008515.jpg
#   inflating: Generate_dataset/images/008539.jpg
#   inflating: Generate_dataset/images/008544.jpg
#   inflating: Generate_dataset/images/008546.jpg
#   inflating: Generate_dataset/images/008554.jpg
#   inflating: Generate_dataset/images/008575.jpg
#   inflating: Generate_dataset/images/008594.jpg
#   inflating: Generate_dataset/images/008609.jpg
#   inflating: Generate_dataset/images/008613.jpg
#   inflating: Generate_dataset/images/008622.jpg
#   inflating: Generate_dataset/images/008632.jpg
#   inflating: Generate_dataset/images/008637.jpg
#   inflating: Generate_dataset/images/008649.jpg
#   inflating: Generate_dataset/images/008651.jpg
#   inflating: Generate_dataset/images/008656.jpg
#   inflating: Generate_dataset/images/008657.jpg
#   inflating: Generate_dataset/images/008658.jpg
#   inflating: Generate_dataset/images/008668.jpg
#   inflating: Generate_dataset/images/008674.jpg
#   inflating: Generate_dataset/images/008684.jpg
#   inflating: Generate_dataset/images/008693.jpg
#   inflating: Generate_dataset/images/008703.jpg
#   inflating: Generate_dataset/images/008705.jpg
#   inflating: Generate_dataset/images/008711.jpg
#   inflating: Generate_dataset/images/008714.jpg
#   inflating: Generate_dataset/images/008715.jpg
#   inflating: Generate_dataset/images/008724.jpg
#   inflating: Generate_dataset/images/008735.jpg
#   inflating: Generate_dataset/images/008736.jpg
#   inflating: Generate_dataset/images/008761.jpg
#   inflating: Generate_dataset/images/008767.jpg
#   inflating: Generate_dataset/images/008777.jpg
#   inflating: Generate_dataset/images/008781.jpg
#   inflating: Generate_dataset/images/008782.jpg
#   inflating: Generate_dataset/images/008788.jpg
#   inflating: Generate_dataset/images/008792.jpg
#   inflating: Generate_dataset/images/008798.jpg
#   inflating: Generate_dataset/images/008800.jpg
#   inflating: Generate_dataset/images/008825.jpg
#   inflating: Generate_dataset/images/008827.jpg
#   inflating: Generate_dataset/images/008830.jpg
#   inflating: Generate_dataset/images/008860.jpg
#   inflating: Generate_dataset/images/008861.jpg
#   inflating: Generate_dataset/images/008866.jpg
#   inflating: Generate_dataset/images/008875.jpg
#   inflating: Generate_dataset/images/008881.jpg
#   inflating: Generate_dataset/images/008889.jpg
#   inflating: Generate_dataset/images/008896.jpg
#   inflating: Generate_dataset/images/008898.jpg
#   inflating: Generate_dataset/images/008903.jpg
#   inflating: Generate_dataset/images/008906.jpg
#   inflating: Generate_dataset/images/008908.jpg
#   inflating: Generate_dataset/images/008924.jpg
#   inflating: Generate_dataset/images/008935.jpg
#   inflating: Generate_dataset/images/008950.jpg
#   inflating: Generate_dataset/images/008964.jpg
#   inflating: Generate_dataset/images/008972.jpg
#   inflating: Generate_dataset/images/008977.jpg
#   inflating: Generate_dataset/images/008986.jpg
#   inflating: Generate_dataset/images/009021.jpg
#   inflating: Generate_dataset/images/009025.jpg
#   inflating: Generate_dataset/images/009030.jpg
#   inflating: Generate_dataset/images/009038.jpg
#   inflating: Generate_dataset/images/009057.jpg
#   inflating: Generate_dataset/images/009061.jpg
#   inflating: Generate_dataset/images/009062.jpg
#   inflating: Generate_dataset/images/009076.jpg
#   inflating: Generate_dataset/images/009081.jpg
#   inflating: Generate_dataset/images/009083.jpg
#   inflating: Generate_dataset/images/009090.jpg
#   inflating: Generate_dataset/images/009096.jpg
#   inflating: Generate_dataset/images/009103.jpg
#   inflating: Generate_dataset/images/009111.jpg
#   inflating: Generate_dataset/images/009132.jpg
#   inflating: Generate_dataset/images/009142.jpg
#   inflating: Generate_dataset/images/009167.jpg
#   inflating: Generate_dataset/images/009176.jpg
#   inflating: Generate_dataset/images/009182.jpg
#   inflating: Generate_dataset/images/009183.jpg
#   inflating: Generate_dataset/images/009188.jpg
#   inflating: Generate_dataset/images/009199.jpg
#   inflating: Generate_dataset/images/009206.jpg
#   inflating: Generate_dataset/images/009210.jpg
#   inflating: Generate_dataset/images/009211.jpg
#   inflating: Generate_dataset/images/009233.jpg
#   inflating: Generate_dataset/images/009234.jpg
#   inflating: Generate_dataset/images/009235.jpg
#   inflating: Generate_dataset/images/009241.jpg
#   inflating: Generate_dataset/images/009243.jpg
#   inflating: Generate_dataset/images/009256.jpg
#   inflating: Generate_dataset/images/009261.jpg
#   inflating: Generate_dataset/images/009262.jpg
#   inflating: Generate_dataset/images/009265.jpg
#   inflating: Generate_dataset/images/009267.jpg
#   inflating: Generate_dataset/images/009276.jpg
#   inflating: Generate_dataset/images/009280.jpg
#   inflating: Generate_dataset/images/009298.jpg
#   inflating: Generate_dataset/images/009304.jpg
#   inflating: Generate_dataset/images/009305.jpg
#   inflating: Generate_dataset/images/009321.jpg
#   inflating: Generate_dataset/images/009329.jpg
#   inflating: Generate_dataset/images/009335.jpg
#   inflating: Generate_dataset/images/009341.jpg
#   inflating: Generate_dataset/images/009346.jpg
#   inflating: Generate_dataset/images/009355.jpg
#   inflating: Generate_dataset/images/009360.jpg
#   inflating: Generate_dataset/images/009381.jpg
#   inflating: Generate_dataset/images/009383.jpg
#   inflating: Generate_dataset/images/009384.jpg
#   inflating: Generate_dataset/images/009387.jpg
#   inflating: Generate_dataset/images/009396.jpg
#   inflating: Generate_dataset/images/009403.jpg
#   inflating: Generate_dataset/images/009426.jpg
#   inflating: Generate_dataset/images/009427.jpg
#   inflating: Generate_dataset/images/009442.jpg
#   inflating: Generate_dataset/images/009447.jpg
#   inflating: Generate_dataset/images/009449.jpg
#   inflating: Generate_dataset/images/009483.jpg
#   inflating: Generate_dataset/images/009485.jpg
#   inflating: Generate_dataset/images/009489.jpg
#   inflating: Generate_dataset/images/009492.jpg
#   inflating: Generate_dataset/images/009498.jpg
#   inflating: Generate_dataset/images/009509.jpg
#   inflating: Generate_dataset/images/009510.jpg
#   inflating: Generate_dataset/images/009513.jpg
#   inflating: Generate_dataset/images/009522.jpg
#   inflating: Generate_dataset/images/009544.jpg
#   inflating: Generate_dataset/images/009552.jpg
#   inflating: Generate_dataset/images/009555.jpg
#   inflating: Generate_dataset/images/009572.jpg
#   inflating: Generate_dataset/images/009575.jpg
#   inflating: Generate_dataset/images/009589.jpg
#   inflating: Generate_dataset/images/009592.jpg
#   inflating: Generate_dataset/images/009604.jpg
#   inflating: Generate_dataset/images/009640.jpg
#   inflating: Generate_dataset/images/009643.jpg
#   inflating: Generate_dataset/images/009652.jpg
#   inflating: Generate_dataset/images/009669.jpg
#   inflating: Generate_dataset/images/009672.jpg
#   inflating: Generate_dataset/images/009675.jpg
#   inflating: Generate_dataset/images/009683.jpg
#   inflating: Generate_dataset/images/009688.jpg
#   inflating: Generate_dataset/images/009694.jpg
#   inflating: Generate_dataset/images/009701.jpg
#   inflating: Generate_dataset/images/009720.jpg
#   inflating: Generate_dataset/images/009723.jpg
#   inflating: Generate_dataset/images/009725.jpg
#   inflating: Generate_dataset/images/009740.jpg
#   inflating: Generate_dataset/images/009744.jpg
#   inflating: Generate_dataset/images/009752.jpg
#   inflating: Generate_dataset/images/009753.jpg
#   inflating: Generate_dataset/images/009757.jpg
#   inflating: Generate_dataset/images/009765.jpg
#   inflating: Generate_dataset/images/009770.jpg
#   inflating: Generate_dataset/images/009777.jpg
#   inflating: Generate_dataset/images/009786.jpg
#   inflating: Generate_dataset/images/009788.jpg
#   inflating: Generate_dataset/images/009799.jpg
#   inflating: Generate_dataset/images/009820.jpg
#   inflating: Generate_dataset/images/009821.jpg
#   inflating: Generate_dataset/images/009826.jpg
#   inflating: Generate_dataset/images/009829.jpg
#   inflating: Generate_dataset/images/009838.jpg
#   inflating: Generate_dataset/images/009849.jpg
#   inflating: Generate_dataset/images/009856.jpg
#   inflating: Generate_dataset/images/009866.jpg
#   inflating: Generate_dataset/images/009873.jpg
#   inflating: Generate_dataset/images/009875.jpg
#   inflating: Generate_dataset/images/009876.jpg
#   inflating: Generate_dataset/images/009883.jpg
#   inflating: Generate_dataset/images/009889.jpg
#   inflating: Generate_dataset/images/009899.jpg
#   inflating: Generate_dataset/images/009919.jpg
#   inflating: Generate_dataset/images/009922.jpg
#   inflating: Generate_dataset/images/009927.jpg
#   inflating: Generate_dataset/images/009936.jpg
#   inflating: Generate_dataset/images/009943.jpg
#   inflating: Generate_dataset/images/009952.jpg
#   inflating: Generate_dataset/images/009956.jpg
#   inflating: Generate_dataset/main.py
#    creating: Generate_dataset/predicted/
#    creating: Generate_dataset/predicted/.ipynb_checkpoints/
#   inflating: Generate_dataset/predicted/.ipynb_checkpoints/009956-checkpoint.txt
#    creating: Generate_dataset/results/
#   inflating: Generate_dataset/results/results.txt
#   inflating: Generate_dataset/voc2007+2012.txt
#   inflating: Generate_dataset/voc2007.txt
#   inflating: Generate_dataset/voc2007test.txt
#   inflating: Generate_dataset/voc2012.txt
#   inflating: util.py

# %% [markdown]
# ## 이후, 다음의 셀을 시행하여 이번 실습에 필요한 라이브러리를 import 하자.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random
import function
import time
import datetime

import math
from util import *
from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1RuugQ9UayctyiBexEDtCGxqTrorZDMKF" alt="no_image" style="width: 800px;"/>
# >
# > - 위 사진을 통해 classification과 detection의 차이를 볼 수 있습니다.
# >
# > - Image classification에서, 전체 image는 single label로 분류됩니다.
# >
# > - 그러나 object detection에서는, 하나의 이미지 안에서 Object를 구체적으로 Localize합니다. 이 때 Object는 여러 개가 될 수 있습니다.
# >
# > - 이미지가 주어지면, Object Detection Network는 총 4개의 output을 출력합니다
# : bounding box, class label, probability score ,confidence score
# >
#
# ### 2. YOLO
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1YGXOBXHFk4PlbII3Rp1b97-P7tkaPAAa" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO는 object detection의 알고리즘 중 하나입니다.
# >
# > - 이 알고리즘은 object detection에서 이미지 픽셀의 bounding box 좌표 및 class의 확률을 얻어내는 과정을 $\bf{single\ regression\ problem}$으로 재구성합니다.
# >
# > - 즉, 이전까지의 알고리즘은 bounding box를 찾고 class label을 분류하고 probability/confidence score를 찾는 과정을 따로 진행했다면, YOLO는 단 한번의 regression으로 이 모든 output을 찾습니다.
# >
# > - 따라서 YOLO를 사용하면 어떤 물체가 있고 어디에 있는지 예측하기 위해 이미지를 한 번만 봅니다(YOLO의 이름 뜻이 You Only Look Once인 이유).
# >
# > - YOLO의 장점은 속도이다. 복잡한 파이프라인을 사용하지 않고 regression 문제로 재구성하기 때문이다.
# >
# > - 참고하면 좋은 링크 : https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. YOLO를 PyTorch로 구축해보자.
#
# > ### YOLO model:
# > - 22개의 Convolutional Layers를 가지고 있다.
# >
# >     - Output size를 맞추기 위해 처음과 and 20번째 convolution layer에는 stride를 2로 설정함
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - 마지막 layer를 제외한 모든 layer에 Leaky ReLu Activation 적용
# ### 4. YOLO는 어떻게 구현되는가?
# >
# > - The input image는 셀의 S $\times$ S grid로 나뉜다.
# >
# > - 각각의 grid 셀은 B(=2) 경계 상자와 C(=20) 클래스 확률을 예측합니다.
# >
# > - 각 bounding box는 x, y, w, h 및 confidence의 5가지의 숫자로 구성됩니다.
# >
# > - (x,y) 좌표는 grid cell의 경계에 대한 상자의 중심을 나타냅니다.
# >
# > - width(w)와 height(h)는 전체 이미지를 기준으로 예측됩니다.
# >
# > - 해당 셀에 object가 없으면 confidence score는 0입니다.
# >
# > -  cell에 object가 포함된 경우 confidence score는 예측된 box와 ground truth 사이의 IoU(Intersection over Union)와 같습니다(**이는 loss function를 구축하는 데 중요함**).
# >
# > - Output vector는 S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)과 같습니다.
# >
# > <img src="https://drive.google.com/uc?export=view&id=17F7RUYkc47l1wp0piFZ45mFvYrust6iq" alt="no_image" style="width: 600px;"/>
# >

# %% [markdown]
# ### Step 1: YOLO network를 구축한다. (**과제**)

# %% [markdown]
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1HzmdnhftYMN4btoElO36mpgJt4GUAJj8" alt="no_image" style="width: 800px;"/>
# >>
# >> - 아래의 표를 보면서 YOLO model을 구축하자.
# >> - **편의를 위해 실제 YOLO 논문의 모델과는 구조가 약간 다르게 설계되어 있습니다. 위의 그림과 아래의 표를 보고 표에 맞게 네트워크를 구성하세요.**
# >> - **self.pre_train_net** 과 **self.post_net** 블럭의 빈칸을 채워주세요.
# >> - 모든 Layer는 negative_slop가 0.01인 Leaky ReLU를 사용합니다. (실제 논문과 다름)
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1wjI5PNCsFIAdRr2qgxv7orGPTuwu8hYL" alt="no_image" style="width: 800px;"/>
# >>
# >> #### **self.post_net**
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1s76_eJPn2E66udpdCAGFSuDptE3NkEl2" alt="no_image" style="width: 800px;"/>
#
# ## Pytorch에서 Convolution, Maxpooling, 그리고 Leaky ReLU를 사용하려면 다음과 같은 코드를 사용하면 된다.
# - Convolution : **nn.Conv2d(in_channels=---,  out_channels=---,  kernel_size=---,  stride=---,  padding=---)**
# - Max pooling : **nn.MaxPool2d(kernel_size=---,  stride=---)**
# - Leaky ReLU : **nn.LeakyReLU(negative_slope=---)**

# %% [markdown]
# ## LeakyReLU란?
# Leaky ReLU (Leaky Rectified Linear Unit)는 활성화 함수의 일종으로, 인공 신경망에서 사용됩니다. 기본 ReLU 활성화 함수의 변형으로, Leaky ReLU는 음수 입력 값에 대해 작은 기울기를 허용하여 기본 ReLU의 "Dead ReLU" 문제를 해결합니다.
#
# Leaky ReLU의 수학적 표현은 다음과 같습니다:
#
# $$
# f(x) = \begin{cases}
# x, & \text{if } x > 0 \\
# \alpha x, & \text{if } x \leq 0
# \end{cases}
# $$
#
# 여기서 $x$는 입력 값이고, $α$는 0보다 큰 작은 상수입니다 (예: 0.01). 이 상수 값은 음수 입력에 대한 출력의 기울기를 결정합니다. $α$가 0이면 Leaky ReLU는 기본 ReLU와 동일하게 작동하며, $α$가 양수이면 음수 입력에 대해 작은 기울기를 갖게 됩니다.
#
# Leaky ReLU의 주요 장점은 다음과 같습니다:
#
# 1. "Dead ReLU" 문제 해결: 기본 ReLU에서는 음수 입력에 대한 출력이 항상 0이므로, 학습 도중 가중치 업데이트가 중단되는 경우가 있습니다. Leaky ReLU는 음수 값에 대해 작은 기울기를 허용함으로써 이 문제를 해결합니다.
# 2. 발산하지 않는 손실: Leaky ReLU는 미분 가능하므로 그래디언트 소실 문제에 덜 민감합니다.
#
# 그러나 Leaky ReLU는 다른 활성화 함수들에 비해 하이퍼파라미터인 α를 선택해야 하는 단점이 있습니다. 이 값은 신경망의 성능에 영향을 미치므로, 최적의 α 값을 찾기 위해 실험을 통해 조정해야 할 수 있습니다.

# %% [markdown]
# # 주의 ! 반드시 nn.Sequential을 사용해서 모델을 구축해주세요. 그렇지 않으면, pre-train된 weight가 load되지 않습니다.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()

        self.pre_train_net = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 192, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(192, 128, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(256, 256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(512, 256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(512, 512, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(512, 1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(1024, 512, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(512, 1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
        )

        self.post_net = nn.Sequential(
            nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(1024, 1024, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
            nn.Conv2d(1024, 1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope = 0.01),
        )

        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )

        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )

        # self.pre_train_net.cuda()
        # self.post_net.cuda()
        # self.FC1.cuda()
        # self.FC2.cuda()

        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ## Summarize : YOLO란?
# YOLO (You Only Look Once)는 실시간 객체 탐지를 위한 컴퓨터 비전 알고리즘입니다. 기존 객체 탐지 방법과 달리, YOLO는 이미지를 단 한 번의 통과로 빠르게 분석하고 객체를 탐지하기 때문에 그 이름이 "You Only Look Once"입니다. YOLO는 정확도는 조금 낮을 수 있지만, 실시간 처리와 빠른 속도에서 큰 이점을 가지고 있습니다.
#
# YOLO 알고리즘의 기본 작동 원리는 다음과 같습니다:
#
# 1. 이미지를 S x S 그리드로 나눕니다. 각 셀은 해당 셀에 중심이 있는 객체를 예측합니다.
#
# 2. 각 셀은 B개의 경계 상자와 해당 객체의 신뢰도 점수를 예측합니다. 신뢰도 점수는 예측된 경계 상자와 실제 경계 상자 간의 IoU (Intersection over Union)를 나타냅니다.
#
# 3. 각 셀은 클래스 확률을 예측합니다. 클래스 확률은 해당 셀에 특정 클래스의 객체가 포함되어 있는 확률입니다.
#
# 4. 경계 상자의 신뢰도 점수와 클래스 확률을 결합하여 최종 예측을 만듭니다. 이를 통해 객체의 위치와 클래스 레이블을 얻습니다.
#
# YOLO는 여러 버전이 있으며, 각 버전마다 성능과 정확도가 개선되었습니다. 가장 최근의 YOLO v4 및 YOLO v5 모델은 이전 버전보다 더 높은 정확도와 빠른 속도를 제공하면서 실시간 객체 탐지에 널리 사용되고 있습니다.

# %% [markdown]
# ## Loss function

# %% [markdown]
# >> - YOLO에서 사용된 loss function은 다음과 같다.
# >> <img src="https://drive.google.com/uc?export=view&id=16Cr4l-1eGFSv97fprHb4Wyc90lYAyOn7" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ 은 다음과 같이 정의된다.
# >>    - 1, object가 grid cell $i$ 와 $j$번째 bounding box predictor에 존재할 경우.
# >>    - 0, otherwise
# >>
# >> - YOLO는 grid cell 하나 당 여러개의 bounding box를 예측한다.(이번 실습에서 구현한 네트워크의 경우, grid cell 당 2개의 bounding box가 예측된다.)
# >> - Train 단계에서, YOLO는 각 object를 담당하는 하나의 bounding box predictor가 필요합니다.
# >> - 이 loss 함수 식은 하나의 predictor가 ground truth에 대해 가장 높은 IoU를 갖는 object를 예측할 수 있도록 해준다.
# >> - loss function은 3개의 파트로 나눌 수 있다.
# >>    1. Classification ( $\bf{6}$ classes )
# >>       <img src="https://drive.google.com/uc?export=view&id=1boBFAagSQqtkuyLcgxO_-rnaLWVVlCrV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - $\mathbb{1}_{obj}$ 을 빼면, 분류에서 사용한 sum-squared error와 유사하다.
# >>
# >>       - cell 안에 object가 없으면 classification error에 페널티를 주지 않는다. (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell
# >>       <img src="https://drive.google.com/uc?export=view&id=1zRXo9wrzsE1igQeZ3NmFEywVmWhZ-EW3" alt="no_image" style="width: 300px;"/>
# >>
# >>       - bounding box predictor와 관련된 confidence score와 관련된 loss를 계산한다.
# >>
# >>       - $\mathbb{1}_{noobj}$ cell에 object가 없을 때 1이고, 그렇지 않으면 0입니다.
# >>    3. Bounding box 좌표 (x,y,h,w)를 regression하고, (4개의 scalar값에 대해),Object confidence에 대한 loss를 부과한다.
# >>       <img src="https://drive.google.com/uc?export=view&id=1BfqNlYbzxfUXgkz5Ls549rpi8TwqxW63" alt="no_image" style="width: 600px;"/>
# >>
# >>       - 예측된 bounding box 좌표 $(x,y)$ 와 width/height $(w,h)$에 대한 loss를 계산한다.
# >>
# >>       - width와 height는 제곱근을 통해 조정된다. 그 이유는, 큰 상자에서의 bounding box 오차에 더 큰 loss를 부여하기 위해서이다.
# >>
# >>       - 또한, Cell 내의 Object에 대한 confidence score의 loss를 계산한다.
# >>
# >> - 논문과 동일하게, $\lambda_{coord} = 5$ 와 $\lambda_{noobj} = 0.5$로 설정하였다.
# >>

# %% [markdown]
# # YOLO의 loss를 구현하는 과정은 정말 어렵습니다. 따라서 코드를 상세히 살펴볼 필요는 없습니다. 궁금하신 분만 보셔도 충분합니다.

# %% [markdown]
# ## Summarize : YOLOv1의 Loss function
# YOLOv1의 손실 함수는 신경망의 출력을 바탕으로 모델이 예측한 경계 상자와 실제 경계 상자 간의 차이를 측정합니다. YOLOv1의 손실 함수는 아래와 같이 4가지 주요 구성 요소로 나눌 수 있습니다.
#
# 좌표 손실 (Coordinate Loss): 모델이 예측한 경계 상자의 중심 좌표 (x, y) 및 너비와 높이 (w, h)와 실제 경계 상자 간의 차이를 측정합니다. 이 손실은 주로 평균 제곱 오차 (MSE)를 사용하여 계산됩니다. 좌표 손실에 가중치 l_coord를 곱하여 전체 손실에 더 큰 영향을 줍니다.
#
# 객체 손실 (Objectness Loss): 예측된 경계 상자에 물체가 존재할 확률 (Objectness Confidence)을 측정합니다. 이 손실도 주로 MSE를 사용하여 계산됩니다. 객체가 존재하는 셀에 대해서만 계산되며, 객체가 없는 셀은 고려하지 않습니다.
#
# 배경 손실 (No-objectness Loss): 예측된 경계 상자에 물체가 없을 확률을 측정합니다. 이 손실은 또한 MSE를 사용하여 계산되며, 객체가 없는 셀에 대해서만 계산됩니다. 전체 손실에 더 작은 영향을 주기 위해 배경 손실에 가중치 l_noobj를 곱합니다.
#
# 분류 손실 (Classification Loss): 신경망이 예측한 클래스 확률과 실제 클래스 간의 차이를 측정합니다. 이 손실은 객체가 존재하는 셀에 대해 계산되며, 주로 MSE를 사용하여 계산됩니다.
#
# YOLOv1의 전체 손실 함수는 이러한 개별 손실 요소들을 모두 합한 것으로 구성됩니다. 이 손실 함수를 최소화함으로써, 모델은 객체의 위치, 크기, 클래스, 그리고 객체 존재 여부를 더 정확하게 예측하도록 학습됩니다. YOLOv1의 손실 함수는 물체 탐지 문제에 맞게 설계되었으며, 경계 상자와 클래스 예측을 동시에 학습할 수 있게 해줍니다.
#
# 이 손실함수에서 항목들 중 일부에 가중치를 다르게 곱해주는 것을 볼 수 있습니다. 그 이유는 다음과 같습니다.
#
# 1. 박스 좌표 손실 (Bounding box coordinate loss): YOLO는 객체의 바운딩 박스를 예측하는데 중점을 두고 있습니다. 그러나 큰 객체와 작은 객체의 위치 오차를 동일하게 다루면 작은 객체의 위치 오차가 상대적으로 크게 무시될 수 있습니다. 이를 균형있게 처리하기 위해 작은 객체에 대한 좌표 손실에 더 큰 가중치를 부여합니다.
#
# 2. 객체 및 배경에 대한 신뢰도 손실 (Confidence loss for objects and background): YOLO는 객체의 존재와 배경을 구별하는 신뢰도를 예측합니다. 일부 영역에서는 객체가 없는 배경이 더 많기 때문에, 배경에 대한 오류가 객체에 대한 오류보다 많을 수 있습니다. 이로 인해 모델이 배경에 과도하게 집중하게 되므로, 객체에 대한 신뢰도 손실에 더 큰 가중치를 부여하여 이 문제를 완화합니다.
#
# 3. 클래스 손실 (Class loss): YOLO는 다중 클래스 객체 탐지를 수행하며, 각 클래스에 대한 확률을 예측합니다. 클래스 손실에 가중치를 조정하여 특정 클래스에 대한 분류 성능을 개선하거나 전체 클래스 간의 균형을 맞추는 데 도움이 됩니다.
#
# 요약하면, YOLO의 손실 함수에서 가중치를 다르게 곱하는 이유는 객체 탐지의 성능을 균형있게 최적화하기 위한 것입니다. 이를 통해 모델이 크기와 위치에 따른 오차를 공정하게 처리하고, 배경과 객체의 신뢰도를 적절하게 구별하며, 다양한 클래스의 객체를 잘 인식할 수 있도록 학습됩니다.

# %% [markdown]
# ### Step 2. Train the model
#
# > - 위의 코드를 기반으로 training을 실행합니다.
# > - *optimizer* 와 *num_epoch* 등은 미리 다 설정해두었습니다.
# > - Object Detection은 학습이 굉장히 오래 걸리는 task 중 하나입니다. 따라서 이번 실습에서는, 미리 pre-train을 해두었습니다.
# > - 모델 구축을 올바르게 하셨다면, 5 epoch(약 10분 가량 소요) 정도만 해줘도 성능이 잘 나올 겁니다.

# %% [markdown]
# # 아래 코드는 따로 수정하거나 추가할 필요 없이 실행시켜주시면 됩니다.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
torch.cuda.is_available()
# Out:
# False

# %%
file_root = './all_img/'
train_dataset = function.YoloDataset(root=file_root, list_file='./Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('/content/pre_train.pt', map_location=torch.device('cpu'))
model.load_state_dict(state_dict['state_dict'])
print('pre_train_complete')

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

criterion = function.yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 5
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)

        pred = model(images)
        loss = criterion(pred, target)

        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-79162534ccf9> in <cell line: 24>()
#      31
#      32         pred = model(images)
# ---> 33         loss = criterion(pred, target)
#      34
#      35         total_loss += loss.item()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /content/function.py in forward(self, pred, target)
#     390         batch_size = pred.size()[0]
#     391
# --> 392         noobj_loss1 = self.not_contain_obj_error(pred, target)
#     393         prob_loss = self.compute_prob_error(pred, target)
#     394         obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)
#
# /content/function.py in not_contain_obj_error(self, pred, target)
#     277
#     278         # Create a mask for selecting the objectness confidence values in the prediction tensor
# --> 279         noobj_conf_mask = torch.cuda.ByteTensor(noobj_pred.size()).fill_(0)
#     280         for b in range(2):
#     281             noobj_conf_mask[:, 4 + b * 5] = 1  # noobj_conf_mask[:, 4] = 1; noobj_conf_mask[:, 9] = 1
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     291         if "CUDA_MODULE_LOADING" not in os.environ:
#     292             os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 293         torch._C._cuda_init()
#     294         # Some of the queued calls may reentrantly call _lazy_init();
#     295         # we need to just return without initializing in that case.
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %% [markdown]
# ### Step 3. Inference
#
#
# >
# > - 직접 테스트해보실 수 있도록 코드를 구성해 두었습니다.
# > - Visualization code를 통해 bounding box가 적절하게 구현되는지 확인 가능합니다.

# %% [markdown]
# ###  Visualization code를 통해 bounding box가 적절하게 구현되는지 확인 가능합니다.

# %% [markdown]
# # 아래 코드도 수정이나 추가 없이 그냥 실행하시면 됩니다.

# %% [markdown]
# # 원하시면, 파일 이름을 변경해보면서 결과를 확인해보세요.

# %%
function.visualize(model, './Generate_dataset/images/000015.jpg')
# Out:
# bicycle0.13

# %%
function.visualize(model, './Generate_dataset/images/000037.jpg')
# Out:
# dog0.46

# %%
function.visualize(model, './Generate_dataset/images/000103.jpg')
# Out:
# car0.15

# %%
function.visualize(model, './Generate_dataset/images/003055.jpg')
# Out:
# car0.42

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
